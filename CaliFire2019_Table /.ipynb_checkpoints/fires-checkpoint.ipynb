# %%
# import depency 
import pandas as pd 
import numpy as np
import requests 
from pandas.io.json import json_normalize
import json
from pprint import pprint
import string
import time
import datetime
from datetime import datetime
from datetime import date

# %%
csv = pd.read_csv('California_Fire_Incidents.csv')
csv
clean = csv[(csv.ArchiveYear >=2019)]
clean.head()
# Out:
#       AcresBurned  Active                                          AdminUnit  \
# 1370       1806.0   False                     Ventura County Fire Department
# 1371       1300.0   False               CAL FIRE Madera-Mariposa-Merced Unit
# 1372       1011.0   False  Unified Command: CAL FIRE/Riverside County Fir...
# 1373        605.0   False                         CAL FIRE Tehama-Glenn Unit
# 1374        494.0   False         CAL FIRE Riverside County Fire Department
#
#       AirTankers  ArchiveYear  CalFireIncident  \
# 1370         NaN         2019             True
# 1371         NaN         2019             True
# 1372         NaN         2019             True
# 1373         NaN         2019             True
# 1374         NaN         2019             True
#
#                                 CanonicalUrl  \
# 1370        /incidents/2019/10/30/easy-fire/
# 1371       /incidents/2019/8/16/gaines-fire/
# 1372  /incidents/2019/10/10/sandalwood-fire/
# ...

# %%
clean.keys()
# Out:
# Index(['AcresBurned', 'Active', 'AdminUnit', 'AirTankers', 'ArchiveYear',
#        'CalFireIncident', 'CanonicalUrl', 'ConditionStatement',
#        'ControlStatement', 'Counties', 'CountyIds', 'CrewsInvolved', 'Dozers',
#        'Engines', 'Extinguished', 'Fatalities', 'Featured', 'Final',
#        'FuelType', 'Helicopters', 'Injuries', 'Latitude', 'Location',
#        'Longitude', 'MajorIncident', 'Name', 'PercentContained',
#        'PersonnelInvolved', 'Public', 'SearchDescription', 'SearchKeywords',
#        'Started', 'Status', 'StructuresDamaged', 'StructuresDestroyed',
#        'StructuresEvacuated', 'StructuresThreatened', 'UniqueId', 'Updated',
#        'WaterTenders'],
#       dtype='object')

# %%
update = clean[['AcresBurned', 'AdminUnit', 
        'ConditionStatement',
        'Counties', 'CountyIds', 'Extinguished', 'Injuries', 'Latitude','Longitude', 'Location',
        'Name', 'PercentContained',
       'PersonnelInvolved', 'SearchDescription',
        'Status', 'UniqueId','ArchiveYear']]
update.head()
# Out:
#       AcresBurned                                          AdminUnit  \
# 1370       1806.0                     Ventura County Fire Department
# 1371       1300.0               CAL FIRE Madera-Mariposa-Merced Unit
# 1372       1011.0  Unified Command: CAL FIRE/Riverside County Fir...
# 1373        605.0                         CAL FIRE Tehama-Glenn Unit
# 1374        494.0         CAL FIRE Riverside County Fire Department
#
#                                      ConditionStatement   Counties CountyIds  \
# 1370  Evacuation Information: <a href= "https://twit...    Ventura        56
# 1371                                                NaN   Mariposa        22
# 1372  For evacuation and road closure information\r\...  Riverside        33
# 1373                                                NaN     Tehama        52
# 1374  Mandatory evacuations and road closures are in...  Riverside        33
#
#               Extinguished  Injuries   Latitude   Longitude  \
# ...

# %%
started = clean.Started.to_list()
end = clean.Updated.to_list()
Started = ""
update['Started'] = pd.DatetimeIndex(started).month
update['Ended'] = pd.DatetimeIndex(end).month
update.head()
# Out:
#       AcresBurned                                          AdminUnit  \
# 1370       1806.0                     Ventura County Fire Department
# 1371       1300.0               CAL FIRE Madera-Mariposa-Merced Unit
# 1372       1011.0  Unified Command: CAL FIRE/Riverside County Fir...
# 1373        605.0                         CAL FIRE Tehama-Glenn Unit
# 1374        494.0         CAL FIRE Riverside County Fire Department
#
#                                      ConditionStatement   Counties CountyIds  \
# 1370  Evacuation Information: <a href= "https://twit...    Ventura        56
# 1371                                                NaN   Mariposa        22
# 1372  For evacuation and road closure information\r\...  Riverside        33
# 1373                                                NaN     Tehama        52
# 1374  Mandatory evacuations and road closures are in...  Riverside        33
#
#               Extinguished  Injuries   Latitude   Longitude  \
# ...

# %%
# Did not concat yet
l= update.Latitude.to_list()
l1= update.Longitude.to_list()
Cord = ''
update[['Latitude','Longitude']]
# Out:
#        Latitude   Longitude
# 1370  34.282179 -118.803389
# 1371  37.536069 -120.177018
# 1372  33.992500 -117.059167
# 1373  40.001710 -122.254210
# 1374  34.017780 -117.462500
# ...         ...         ...
# 1631  33.827979 -117.499619
# 1632  39.409722 -121.000556
# 1633  38.734634 -121.729691
# 1634  33.351145 -117.403719
# 1635  33.451480 -116.058980
#
# [266 rows x 2 columns]

# %%
# combined lat and lon
Cord = ''
update['Cord'] = list(zip(update.Latitude,update.Longitude))
update.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3a5d69a478ad> in <module>
#       1 # combined lat and lon
#       2 Cord = ''
# ----> 3 update['Cord'] = list(zip(update.Latitude,update.Longitude))
#       4 update.head()
#
# NameError: name 'update' is not defined
